# %%
import pandas as pd
import numpy as np

# %%
df_aop=pd.read_csv(
    r'../data/raw/2025-10-09-comagri-communes-aires-ao.csv',
    sep=';',
    encoding='latin1'
)

# %%
df_aop.head()
# Out:
#       CI Département                Commune   Art  \
# 0  01001         AIN  Abergement-Clémenciat  (L')
# 1  01001         AIN  Abergement-Clémenciat  (L')
# 2  01001         AIN  Abergement-Clémenciat  (L')
# 3  01001         AIN  Abergement-Clémenciat  (L')
# 4  01002         AIN    Abergement-de-Varey  (L')
#
#                                    Aire géographique   IDA
# 0                                   Beurre de Bresse  2225
# 1                                    Crème de Bresse  2339
# 2                                    Dinde de Bresse  1498
# 3  Volaille de Bresse ou poulet de Bresse, poular...  1959
# 4                                              Bugey  1597

# %%
df_aop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65484 entries, 0 to 65483
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CI                 65484 non-null  object
#  1   Département        65484 non-null  object
#  2   Commune            65484 non-null  object
#  3   Art                4597 non-null   object
#  4   Aire géographique  65484 non-null  object
#  5   IDA                65484 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 3.0+ MB

# %%
df_aop.rename(columns={
    'CI': 'CP',
    'Aire géographique':'AOC/AOP',
})
# Out:
#           CP Département                Commune   Art  \
# 0      01001         AIN  Abergement-Clémenciat  (L')
# 1      01001         AIN  Abergement-Clémenciat  (L')
# 2      01001         AIN  Abergement-Clémenciat  (L')
# 3      01001         AIN  Abergement-Clémenciat  (L')
# 4      01002         AIN    Abergement-de-Varey  (L')
# ...      ...         ...                    ...   ...
# 65479  89484       YONNE                 Volgré   NaN
# 65480  89484       YONNE                 Volgré   NaN
# 65481  89484       YONNE                 Volgré   NaN
# 65482  89484       YONNE                 Volgré   NaN
# 65483  89486       YONNE               Yrouerre   NaN
#
#                                                  AOC/AOP   IDA
# 0                                       Beurre de Bresse  2225
# 1                                        Crème de Bresse  2339
# 2                                        Dinde de Bresse  1498
# ...

# %%
df_aop=df_aop.drop(columns='Art')

# %%
df_aop.to_csv(
    r'../data/processed/aop.csv' 
    )
